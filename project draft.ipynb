# %% [markdown]
# ### Total de files '.txt' en /data= 3963

# %%
import os

def count_files(directory):
    count = 0
    for root, dirs, files in os.walk(directory):
        for file in files:
            if not file.endswith('.zip'):
                count += 1
    return count

directory = 'data'
file_count = count_files(directory)
print(f'There are {file_count} files in the "{directory}" folder excluding .zip files.')
# Out:
# There are 3963 files in the "data" folder excluding .zip files.

# %% [markdown]
# ### Desgloce de files dentro de cada folder
# 821+821+1668+574+78=3962
#
# news_eng + news_espa + News40 + landmarks + municipios

# %%
import os

def list_files_in_subdirectories(base_directory, subdirectories):
    subdirectory_files = {}
    
    for subdirectory in subdirectories:
        full_path = os.path.join(base_directory, subdirectory)
        if os.path.exists(full_path):
            files = []
            for root, dirs, file_list in os.walk(full_path):
                for file in file_list:
                    if not file.endswith('.zip'):
                        files.append(file)
            file_details = [{'name': f, 'extension': os.path.splitext(f)[1]} for f in files]
            subdirectory_files[subdirectory] = file_details
        else:
            subdirectory_files[subdirectory] = None
    
    return subdirectory_files

base_directory = 'data'
subdirectories = [
    'elmundo_chunked_en_page1_15years',
    'elmundo_chunked_es_page1_15years',
    'elmundo_chunked_es_page1_40years',
    'landmarks',
    'municipalities'
]

subdirectory_files = list_files_in_subdirectories(base_directory, subdirectories)

for subdirectory, files in subdirectory_files.items():
    if files is not None:
        print(f'Files in {subdirectory}:')
        print(f'Total files: {len(files)}')
        for file in files:
            print(f'  - {file["name"]} (Format: {file["extension"]})')
    else:
        print(f'{subdirectory} does not exist.')
# Out:
# Files in elmundo_chunked_en_page1_15years:
# Total files: 821
#   - 19200103_1.txt (Format: .txt)
#   - 19200110_1.txt (Format: .txt)
#   - 19200117_1.txt (Format: .txt)
#   - 19200124_1.txt (Format: .txt)
#   - 19200131_1.txt (Format: .txt)
#   - 19200207_1.txt (Format: .txt)
#   - 19200214_1.txt (Format: .txt)
#   - 19200221_1.txt (Format: .txt)
#   - 19200228_1.txt (Format: .txt)
#   - 19200306_1.txt (Format: .txt)
#   - 19200313_1.txt (Format: .txt)
#   - 19200327_1.txt (Format: .txt)
#   - 19200403_1.txt (Format: .txt)
#   - 19200410_1.txt (Format: .txt)
#   - 19200417_1.txt (Format: .txt)
#   - 19200424_1.txt (Format: .txt)
#   - 19200501_1.txt (Format: .txt)
#   - 19200508_1.txt (Format: .txt)
#   - 19200522_1.txt (Format: .txt)
#   - 19200529_1.txt (Format: .txt)
#   - 19200605_1.txt (Format: .txt)
#   - 19200612_1.txt (Format: .txt)
#   - 19200619_1.txt (Format: .txt)
#   - 19200626_1.txt (Format: .txt)
#   - 19200703_1.txt (Format: .txt)
#   - 19200710_1.txt (Format: .txt)
#   - 19200717_1.txt (Format: .txt)
#   - 19200724_1.txt (Format: .txt)
#   - 19200731_1.txt (Format: .txt)
#   - 19200807_1.txt (Format: .txt)
#   - 19200814_1.txt (Format: .txt)
#   - 19200821_1.txt (Format: .txt)
#   - 19200828_1.txt (Format: .txt)
#   - 19200904_1.txt (Format: .txt)
#   - 19200911_1.txt (Format: .txt)
#   - 19200918_1.txt (Format: .txt)
#   - 19271210_1.txt (Format: .txt)
#   - 19271217_1.txt (Format: .txt)
#   - 19271224_1.txt (Format: .txt)
#   - 19271231_1.txt (Format: .txt)
#   - 19280107_1.txt (Format: .txt)
#   - 19280114_1.txt (Format: .txt)
#   - 19280121_1.txt (Format: .txt)
#   - 19280128_1.txt (Format: .txt)
#   - 19280204_1.txt (Format: .txt)
#   - 19280211_1.txt (Format: .txt)
#   - 19280218_1.txt (Format: .txt)
#   - 19280225_1.txt (Format: .txt)
#   - 19280303_1.txt (Format: .txt)
#   - 19280310_1.txt (Format: .txt)
#   - 19280317_1.txt (Format: .txt)
#   - 19280324_1.txt (Format: .txt)
#   - 19280331_1.txt (Format: .txt)
#   - 19280407_1.txt (Format: .txt)
#   - 19280414_1.txt (Format: .txt)
#   - 19280421_1.txt (Format: .txt)
#   - 19280428_1.txt (Format: .txt)
#   - 19280505_1.txt (Format: .txt)
#   - 19280512_1.txt (Format: .txt)
#   - 19280519_1.txt (Format: .txt)
#   - 19280526_1.txt (Format: .txt)
#   - 19280602_1.txt (Format: .txt)
#   - 19280609_1.txt (Format: .txt)
#   - 19280616_1.txt (Format: .txt)
#   - 19280623_1.txt (Format: .txt)
#   - 19280630_1.txt (Format: .txt)
#   - 19280707_1.txt (Format: .txt)
#   - 19280714_1.txt (Format: .txt)
#   - 19280721_1.txt (Format: .txt)
#   - 19280728_1.txt (Format: .txt)
#   - 19280804_1.txt (Format: .txt)
#   - 19280811_1.txt (Format: .txt)
#   - 19280818_1.txt (Format: .txt)
#   - 19280825_1.txt (Format: .txt)
#   - 19280901_1.txt (Format: .txt)
#   - 19280908_1.txt (Format: .txt)
#   - 19280922_1.txt (Format: .txt)
#   - 19280929_1.txt (Format: .txt)
#   - 19281006_1.txt (Format: .txt)
#   - 19281013_1.txt (Format: .txt)
#   - 19281020_1.txt (Format: .txt)
#   - 19281027_1.txt (Format: .txt)
#   - 19281103_1.txt (Format: .txt)
#   - 19281110_1.txt (Format: .txt)
#   - 19281117_1.txt (Format: .txt)
#   - 19281124_1.txt (Format: .txt)
#   - 19281201_1.txt (Format: .txt)
#   - 19281208_1.txt (Format: .txt)
#   - 19281215_1.txt (Format: .txt)
#   - 19281222_1.txt (Format: .txt)
#   - 19281229_1.txt (Format: .txt)
#   - 19290105_1.txt (Format: .txt)
#   - 19290112_1.txt (Format: .txt)
#   - 19290119_1.txt (Format: .txt)
#   - 19290126_1.txt (Format: .txt)
#   - 19290202_1.txt (Format: .txt)
#   - 19290209_1.txt (Format: .txt)
#   - 19290216_1.txt (Format: .txt)
#   - 19290223_1.txt (Format: .txt)
#   - 19290302_1.txt (Format: .txt)
#   - 19290309_1.txt (Format: .txt)
#   - 19290316_1.txt (Format: .txt)
#   - 19290323_1.txt (Format: .txt)
#   - 19290330_1.txt (Format: .txt)
#   - 19290406_1.txt (Format: .txt)
#   - 19290413_1.txt (Format: .txt)
#   - 19290420_1.txt (Format: .txt)
#   - 19290427_1.txt (Format: .txt)
#   - 19290504_1.txt (Format: .txt)
#   - 19290511_1.txt (Format: .txt)
#   - 19480821_1.txt (Format: .txt)
#   - 19480828_1.txt (Format: .txt)
#   - 19480904_1.txt (Format: .txt)
#   - 19480911_1.txt (Format: .txt)
#   - 19480918_1.txt (Format: .txt)
#   - 19480925_1.txt (Format: .txt)
#   - 19481002_1.txt (Format: .txt)
#   - 19481009_1.txt (Format: .txt)
#   - 19481016_1.txt (Format: .txt)
#   - 19481023_1.txt (Format: .txt)
#   - 19481030_1.txt (Format: .txt)
#   - 19481106_1.txt (Format: .txt)
#   - 19481113_1.txt (Format: .txt)
#   - 19481120_1.txt (Format: .txt)
#   - 19481127_1.txt (Format: .txt)
#   - 19481204_1.txt (Format: .txt)
#   - 19481211_1.txt (Format: .txt)
#   - 19481218_1.txt (Format: .txt)
#   - 19490108_1.txt (Format: .txt)
#   - 19490115_1.txt (Format: .txt)
#   - 19490122_1.txt (Format: .txt)
#   - 19490129_1.txt (Format: .txt)
#   - 19490205_1.txt (Format: .txt)
#   - 19490212_1.txt (Format: .txt)
#   - 19490219_1.txt (Format: .txt)
#   - 19490226_1.txt (Format: .txt)
#   - 19490305_1.txt (Format: .txt)
#   - 19490312_1.txt (Format: .txt)
#   - 19490319_1.txt (Format: .txt)
#   - 19490326_1.txt (Format: .txt)
#   - 19490402_1.txt (Format: .txt)
#   - 19490409_1.txt (Format: .txt)
#   - 19490416_1.txt (Format: .txt)
#   - 19490423_1.txt (Format: .txt)
#   - 19490430_1.txt (Format: .txt)
#   - 19490507_1.txt (Format: .txt)
#   - 19490514_1.txt (Format: .txt)
#   - 19490521_1.txt (Format: .txt)
#   - 19490528_1.txt (Format: .txt)
#   - 19490604_1.txt (Format: .txt)
#   - 19490611_1.txt (Format: .txt)
#   - 19490618_1.txt (Format: .txt)
#   - 19490625_1.txt (Format: .txt)
#   - 19490702_1.txt (Format: .txt)
#   - 19490709_1.txt (Format: .txt)
#   - 19490716_1.txt (Format: .txt)
#   - 19490723_1.txt (Format: .txt)
#   - 19490730_1.txt (Format: .txt)
#   - 19490806_1.txt (Format: .txt)
#   - 19490813_1.txt (Format: .txt)
#   - 19490820_1.txt (Format: .txt)
#   - 19490827_1.txt (Format: .txt)
#   - 19490903_1.txt (Format: .txt)
#   - 19490910_1.txt (Format: .txt)
#   - 19490917_1.txt (Format: .txt)
#   - 19490924_1.txt (Format: .txt)
#   - 19491001_1.txt (Format: .txt)
#   - 19491008_1.txt (Format: .txt)
#   - 19491015_1.txt (Format: .txt)
#   - 19491022_1.txt (Format: .txt)
#   - 19491029_1.txt (Format: .txt)
#   - 19491105_1.txt (Format: .txt)
#   - 19491112_1.txt (Format: .txt)
#   - 19491119_1.txt (Format: .txt)
#   - 19491126_1.txt (Format: .txt)
#   - 19491203_1.txt (Format: .txt)
#   - 19491210_1.txt (Format: .txt)
#   - 19491217_1.txt (Format: .txt)
#   - 19491224_1.txt (Format: .txt)
#   - 19491231_1.txt (Format: .txt)
#   - 19500107_1.txt (Format: .txt)
#   - 19500114_1.txt (Format: .txt)
#   - 19500121_1.txt (Format: .txt)
#   - 19500128_1.txt (Format: .txt)
#   - 19500204_1.txt (Format: .txt)
#   - 19500211_1.txt (Format: .txt)
#   - 19500218_1.txt (Format: .txt)
#   - 19500225_1.txt (Format: .txt)
#   - 19500304_1.txt (Format: .txt)
#   - 19500311_1.txt (Format: .txt)
#   - 19500318_1.txt (Format: .txt)
#   - 19500325_1.txt (Format: .txt)
#   - 19500401_1.txt (Format: .txt)
#   - 19500408_1.txt (Format: .txt)
#   - 19500415_1.txt (Format: .txt)
#   - 19500422_1.txt (Format: .txt)
#   - 19500429_1.txt (Format: .txt)
#   - 19500506_1.txt (Format: .txt)
#   - 19500513_1.txt (Format: .txt)
#   - 19500520_1.txt (Format: .txt)
#   - 19500527_1.txt (Format: .txt)
#   - 19500603_1.txt (Format: .txt)
#   - 19500610_1.txt (Format: .txt)
#   - 19500617_1.txt (Format: .txt)
#   - 19500624_1.txt (Format: .txt)
#   - 19500701_1.txt (Format: .txt)
#   - 19500708_1.txt (Format: .txt)
#   - 19500715_1.txt (Format: .txt)
#   - 19500722_1.txt (Format: .txt)
#   - 19500729_1.txt (Format: .txt)
#   - 19500805_1.txt (Format: .txt)
#   - 19500812_1.txt (Format: .txt)
#   - 19500819_1.txt (Format: .txt)
#   - 19500826_1.txt (Format: .txt)
#   - 19500902_1.txt (Format: .txt)
#   - 19500909_1.txt (Format: .txt)
#   - 19500916_1.txt (Format: .txt)
#   - 19500923_1.txt (Format: .txt)
#   - 19500930_1.txt (Format: .txt)
#   - 19501007_1.txt (Format: .txt)
#   - 19501014_1.txt (Format: .txt)
#   - 19501021_1.txt (Format: .txt)
#   - 19501028_1.txt (Format: .txt)
#   - 19501104_1.txt (Format: .txt)
#   - 19501111_1.txt (Format: .txt)
#   - 19501118_1.txt (Format: .txt)
#   - 19501125_1.txt (Format: .txt)
#   - 19501202_1.txt (Format: .txt)
#   - 19501209_1.txt (Format: .txt)
#   - 19501216_1.txt (Format: .txt)
#   - 19501223_1.txt (Format: .txt)
#   - 19501230_1.txt (Format: .txt)
# Files in elmundo_chunked_es_page1_15years:
# Total files: 821
#   - 19200103.txt (Format: .txt)
#   - 19200110.txt (Format: .txt)
#   - 19200117.txt (Format: .txt)
#   - 19200124.txt (Format: .txt)
#   - 19200131.txt (Format: .txt)
#   - 19200207.txt (Format: .txt)
#   - 19200214.txt (Format: .txt)
#   - 19200221.txt (Format: .txt)
#   - 19200228.txt (Format: .txt)
#   - 19200306.txt (Format: .txt)
#   - 19200313.txt (Format: .txt)
#   - 19200327.txt (Format: .txt)
#   - 19200403.txt (Format: .txt)
#   - 19200410.txt (Format: .txt)
#   - 19200417.txt (Format: .txt)
#   - 19200424.txt (Format: .txt)
#   - 19200501.txt (Format: .txt)
#   - 19200508.txt (Format: .txt)
#   - 19200522.txt (Format: .txt)
#   - 19200529.txt (Format: .txt)
#   - 19200605.txt (Format: .txt)
#   - 19200612.txt (Format: .txt)
#   - 19200619.txt (Format: .txt)
#   - 19200626.txt (Format: .txt)
#   - 19200703.txt (Format: .txt)
#   - 19200710.txt (Format: .txt)
#   - 19200717.txt (Format: .txt)
#   - 19200724.txt (Format: .txt)
#   - 19200731.txt (Format: .txt)
#   - 19200807.txt (Format: .txt)
#   - 19200814.txt (Format: .txt)
#   - 19200821.txt (Format: .txt)
#   - 19200828.txt (Format: .txt)
#   - 19200904.txt (Format: .txt)
#   - 19200911.txt (Format: .txt)
#   - 19200918.txt (Format: .txt)
#   - 19200925.txt (Format: .txt)
#   - 19201002.txt (Format: .txt)
#   - 19201009.txt (Format: .txt)
#   - 19201016.txt (Format: .txt)
#   - 19201023.txt (Format: .txt)
#   - 19201030.txt (Format: .txt)
#   - 19201106.txt (Format: .txt)
#   - 19201113.txt (Format: .txt)
#   - 19201120.txt (Format: .txt)
#   - 19201204.txt (Format: .txt)
#   - 19201211.txt (Format: .txt)
#   - 19201218.txt (Format: .txt)
#   - 19210108.txt (Format: .txt)
#   - 19210115.txt (Format: .txt)
#   - 19210122.txt (Format: .txt)
#   - 19210129.txt (Format: .txt)
#   - 19210205.txt (Format: .txt)
#   - 19210212.txt (Format: .txt)
#   - 19210219.txt (Format: .txt)
#   - 19210226.txt (Format: .txt)
#   - 19210305.txt (Format: .txt)
#   - 19210312.txt (Format: .txt)
#   - 19210319.txt (Format: .txt)
#   - 19210326.txt (Format: .txt)
#   - 19210402.txt (Format: .txt)
#   - 19210409.txt (Format: .txt)
#   - 19210416.txt (Format: .txt)
#   - 19210423.txt (Format: .txt)
#   - 19210430.txt (Format: .txt)
#   - 19210507.txt (Format: .txt)
#   - 19210521.txt (Format: .txt)
#   - 19210528.txt (Format: .txt)
#   - 19210604.txt (Format: .txt)
#   - 19210611.txt (Format: .txt)
#   - 19210618.txt (Format: .txt)
#   - 19210625.txt (Format: .txt)
#   - 19210702.txt (Format: .txt)
#   - 19210709.txt (Format: .txt)
#   - 19210716.txt (Format: .txt)
#   - 19210723.txt (Format: .txt)
#   - 19210730.txt (Format: .txt)
#   - 19210806.txt (Format: .txt)
#   - 19210813.txt (Format: .txt)
#   - 19210820.txt (Format: .txt)
#   - 19210827.txt (Format: .txt)
#   - 19210903.txt (Format: .txt)
#   - 19210910.txt (Format: .txt)
#   - 19210917.txt (Format: .txt)
#   - 19210924.txt (Format: .txt)
#   - 19211001.txt (Format: .txt)
#   - 19211008.txt (Format: .txt)
#   - 19211015.txt (Format: .txt)
#   - 19211022.txt (Format: .txt)
#   - 19211029.txt (Format: .txt)
#   - 19211105.txt (Format: .txt)
#   - 19211112.txt (Format: .txt)
#   - 19211119.txt (Format: .txt)
#   - 19211126.txt (Format: .txt)
#   - 19211203.txt (Format: .txt)
#   - 19211210.txt (Format: .txt)
#   - 19211217.txt (Format: .txt)
#   - 19211224.txt (Format: .txt)
#   - 19211231.txt (Format: .txt)
#   - 19220107.txt (Format: .txt)
#   - 19220114.txt (Format: .txt)
#   - 19220121.txt (Format: .txt)
#   - 19220128.txt (Format: .txt)
#   - 19220204.txt (Format: .txt)
#   - 19220211.txt (Format: .txt)
#   - 19220218.txt (Format: .txt)
#   - 19220225.txt (Format: .txt)
#   - 19220304.txt (Format: .txt)
#   - 19220311.txt (Format: .txt)
#   - 19220318.txt (Format: .txt)
#   - 19220325.txt (Format: .txt)
#   - 19220401.txt (Format: .txt)
#   - 19220408.txt (Format: .txt)
#   - 19220415.txt (Format: .txt)
#   - 19220422.txt (Format: .txt)
#   - 19220429.txt (Format: .txt)
#   - 19220506.txt (Format: .txt)
#   - 19220513.txt (Format: .txt)
#   - 19220520.txt (Format: .txt)
#   - 19220527.txt (Format: .txt)
#   - 19220603.txt (Format: .txt)
#   - 19220610.txt (Format: .txt)
#   - 19220617.txt (Format: .txt)
#   - 19220624.txt (Format: .txt)
#   - 19220701.txt (Format: .txt)
#   - 19220708.txt (Format: .txt)
#   - 19220715.txt (Format: .txt)
#   - 19220722.txt (Format: .txt)
#   - 19220729.txt (Format: .txt)
#   - 19220805.txt (Format: .txt)
#   - 19220812.txt (Format: .txt)
#   - 19220819.txt (Format: .txt)
#   - 19220826.txt (Format: .txt)
#   - 19220902.txt (Format: .txt)
#   - 19220909.txt (Format: .txt)
#   - 19220916.txt (Format: .txt)
#   - 19220923.txt (Format: .txt)
#   - 19220930.txt (Format: .txt)
#   - 19221007.txt (Format: .txt)
#   - 19221014.txt (Format: .txt)
#   - 19221021.txt (Format: .txt)
#   - 19221028.txt (Format: .txt)
#   - 19221104.txt (Format: .txt)
#   - 19221111.txt (Format: .txt)
#   - 19221118.txt (Format: .txt)
#   - 19221125.txt (Format: .txt)
#   - 19221202.txt (Format: .txt)
#   - 19221209.txt (Format: .txt)
#   - 19221216.txt (Format: .txt)
#   - 19221223.txt (Format: .txt)
#   - 19221230.txt (Format: .txt)
#   - 19230106.txt (Format: .txt)
#   - 19230113.txt (Format: .txt)
#   - 19230120.txt (Format: .txt)
#   - 19230127.txt (Format: .txt)
#   - 19230203.txt (Format: .txt)
#   - 19230210.txt (Format: .txt)
#   - 19230217.txt (Format: .txt)
#   - 19230224.txt (Format: .txt)
#   - 19230303.txt (Format: .txt)
#   - 19230310.txt (Format: .txt)
#   - 19230317.txt (Format: .txt)
#   - 19230324.txt (Format: .txt)
#   - 19230331.txt (Format: .txt)
#   - 19230407.txt (Format: .txt)
#   - 19230414.txt (Format: .txt)
#   - 19230421.txt (Format: .txt)
#   - 19230428.txt (Format: .txt)
#   - 19230505.txt (Format: .txt)
#   - 19230512.txt (Format: .txt)
#   - 19230519.txt (Format: .txt)
#   - 19230526.txt (Format: .txt)
#   - 19230602.txt (Format: .txt)
#   - 19230609.txt (Format: .txt)
#   - 19230616.txt (Format: .txt)
#   - 19230623.txt (Format: .txt)
#   - 19230630.txt (Format: .txt)
#   - 19230707.txt (Format: .txt)
#   - 19230714.txt (Format: .txt)
#   - 19230721.txt (Format: .txt)
#   - 19230728.txt (Format: .txt)
#   - 19230804.txt (Format: .txt)
#   - 19230811.txt (Format: .txt)
#   - 19230818.txt (Format: .txt)
#   - 19230825.txt (Format: .txt)
#   - 19230901.txt (Format: .txt)
#   - 19230908.txt (Format: .txt)
#   - 19230915.txt (Format: .txt)
#   - 19230922.txt (Format: .txt)
#   - 19230929.txt (Format: .txt)
#   - 19231006.txt (Format: .txt)
#   - 19231013.txt (Format: .txt)
#   - 19231020.txt (Format: .txt)
#   - 19231027.txt (Format: .txt)
#   - 19231103.txt (Format: .txt)
#   - 19231110.txt (Format: .txt)
#   - 19231117.txt (Format: .txt)
#   - 19231124.txt (Format: .txt)
#   - 19231201.txt (Format: .txt)
#   - 19231208.txt (Format: .txt)
#   - 19231215.txt (Format: .txt)
#   - 19231222.txt (Format: .txt)
#   - 19231229.txt (Format: .txt)
#   - 19240105.txt (Format: .txt)
#   - 19240112.txt (Format: .txt)
#   - 19240119.txt (Format: .txt)
#   - 19240126.txt (Format: .txt)
#   - 19240202.txt (Format: .txt)
#   - 19240209.txt (Format: .txt)
#   - 19240216.txt (Format: .txt)
#   - 19240223.txt (Format: .txt)
#   - 19240301.txt (Format: .txt)
#   - 19240308.txt (Format: .txt)
#   - 19240315.txt (Format: .txt)
#   - 19240322.txt (Format: .txt)
#   - 19240329.txt (Format: .txt)
#   - 19240405.txt (Format: .txt)
#   - 19240412.txt (Format: .txt)
#   - 19240419.txt (Format: .txt)
#   - 19240426.txt (Format: .txt)
#   - 19240503.txt (Format: .txt)
#   - 19240510.txt (Format: .txt)
#   - 19240517.txt (Format: .txt)
#   - 19240524.txt (Format: .txt)
#   - 19240531.txt (Format: .txt)
#   - 19240607.txt (Format: .txt)
#   - 19240614.txt (Format: .txt)
#   - 19240621.txt (Format: .txt)
#   - 19240628.txt (Format: .txt)
#   - 19240705.txt (Format: .txt)
#   - 19240712.txt (Format: .txt)
#   - 19240719.txt (Format: .txt)
#   - 19240726.txt (Format: .txt)
#   - 19240802.txt (Format: .txt)
#   - 19240809.txt (Format: .txt)
#   - 19240816.txt (Format: .txt)
#   - 19240823.txt (Format: .txt)
#   - 19240830.txt (Format: .txt)
#   - 19240906.txt (Format: .txt)
#   - 19240913.txt (Format: .txt)
#   - 19240920.txt (Format: .txt)
#   - 19240927.txt (Format: .txt)
#   - 19241004.txt (Format: .txt)
#   - 19241011.txt (Format: .txt)
#   - 19241018.txt (Format: .txt)
#   - 19241025.txt (Format: .txt)
#   - 19241101.txt (Format: .txt)
#   - 19241108.txt (Format: .txt)
#   - 19241115.txt (Format: .txt)
#   - 19241122.txt (Format: .txt)
#   - 19241129.txt (Format: .txt)
#   - 19241206.txt (Format: .txt)
#   - 19241213.txt (Format: .txt)
#   - 19241220.txt (Format: .txt)
#   - 19241227.txt (Format: .txt)
#   - 19250103.txt (Format: .txt)
#   - 19250110.txt (Format: .txt)
#   - 19250117.txt (Format: .txt)
#   - 19250124.txt (Format: .txt)
#   - 19250131.txt (Format: .txt)
#   - 19250207.txt (Format: .txt)
#   - 19250214.txt (Format: .txt)
#   - 19250221.txt (Format: .txt)
#   - 19250228.txt (Format: .txt)
#   - 19250307.txt (Format: .txt)
#   - 19250314.txt (Format: .txt)
#   - 19250321.txt (Format: .txt)
#   - 19250328.txt (Format: .txt)
#   - 19250404.txt (Format: .txt)
#   - 19250411.txt (Format: .txt)
#   - 19250418.txt (Format: .txt)
#   - 19250425.txt (Format: .txt)
#   - 19250502.txt (Format: .txt)
#   - 19250509.txt (Format: .txt)
#   - 19250516.txt (Format: .txt)
#   - 19250523.txt (Format: .txt)
#   - 19250530.txt (Format: .txt)
#   - 19250606.txt (Format: .txt)
#   - 19250613.txt (Format: .txt)
#   - 19250620.txt (Format: .txt)
#   - 19250627.txt (Format: .txt)
#   - 19250711.txt (Format: .txt)
#   - 19250718.txt (Format: .txt)
#   - 19250725.txt (Format: .txt)
#   - 19250801.txt (Format: .txt)
#   - 19250808.txt (Format: .txt)
#   - 19250815.txt (Format: .txt)
#   - 19250822.txt (Format: .txt)
#   - 19250829.txt (Format: .txt)
#   - 19250905.txt (Format: .txt)
#   - 19250912.txt (Format: .txt)
#   - 19250919.txt (Format: .txt)
#   - 19250926.txt (Format: .txt)
#   - 19251003.txt (Format: .txt)
#   - 19251010.txt (Format: .txt)
#   - 19251017.txt (Format: .txt)
#   - 19251024.txt (Format: .txt)
#   - 19251031.txt (Format: .txt)
#   - 19251107.txt (Format: .txt)
#   - 19251114.txt (Format: .txt)
#   - 19251121.txt (Format: .txt)
#   - 19251128.txt (Format: .txt)
#   - 19251205.txt (Format: .txt)
#   - 19251212.txt (Format: .txt)
#   - 19251219.txt (Format: .txt)
#   - 19251226.txt (Format: .txt)
#   - 19260102.txt (Format: .txt)
#   - 19260109.txt (Format: .txt)
#   - 19260116.txt (Format: .txt)
#   - 19260123.txt (Format: .txt)
#   - 19260130.txt (Format: .txt)
#   - 19260206.txt (Format: .txt)
#   - 19260213.txt (Format: .txt)
#   - 19260220.txt (Format: .txt)
#   - 19260227.txt (Format: .txt)
#   - 19260306.txt (Format: .txt)
#   - 19260313.txt (Format: .txt)
#   - 19260320.txt (Format: .txt)
#   - 19260327.txt (Format: .txt)
#   - 19260410.txt (Format: .txt)
#   - 19260417.txt (Format: .txt)
#   - 19260424.txt (Format: .txt)
#   - 19260501.txt (Format: .txt)
#   - 19260508.txt (Format: .txt)
#   - 19260515.txt (Format: .txt)
#   - 19260522.txt (Format: .txt)
#   - 19260529.txt (Format: .txt)
#   - 19260605.txt (Format: .txt)
#   - 19260612.txt (Format: .txt)
#   - 19260619.txt (Format: .txt)
#   - 19260626.txt (Format: .txt)
#   - 19260703.txt (Format: .txt)
#   - 19260710.txt (Format: .txt)
#   - 19260717.txt (Format: .txt)
#   - 19260724.txt (Format: .txt)
#   - 19260731.txt (Format: .txt)
#   - 19260807.txt (Format: .txt)
#   - 19260814.txt (Format: .txt)
#   - 19260821.txt (Format: .txt)
#   - 19260828.txt (Format: .txt)
#   - 19260904.txt (Format: .txt)
#   - 19260911.txt (Format: .txt)
#   - 19260918.txt (Format: .txt)
#   - 19260925.txt (Format: .txt)
#   - 19261002.txt (Format: .txt)
#   - 19261009.txt (Format: .txt)
#   - 19261016.txt (Format: .txt)
#   - 19261023.txt (Format: .txt)
#   - 19261030.txt (Format: .txt)
#   - 19261106.txt (Format: .txt)
#   - 19261113.txt (Format: .txt)
#   - 19261120.txt (Format: .txt)
#   - 19261127.txt (Format: .txt)
#   - 19261204.txt (Format: .txt)
#   - 19261211.txt (Format: .txt)
#   - 19261218.txt (Format: .txt)
#   - 19270108.txt (Format: .txt)
#   - 19270115.txt (Format: .txt)
#   - 19270122.txt (Format: .txt)
#   - 19270129.txt (Format: .txt)
#   - 19270205.txt (Format: .txt)
#   - 19270212.txt (Format: .txt)
#   - 19270219.txt (Format: .txt)
#   - 19270226.txt (Format: .txt)
#   - 19270305.txt (Format: .txt)
#   - 19270312.txt (Format: .txt)
#   - 19270319.txt (Format: .txt)
#   - 19270326.txt (Format: .txt)
#   - 19270402.txt (Format: .txt)
#   - 19270409.txt (Format: .txt)
#   - 19270416.txt (Format: .txt)
#   - 19270423.txt (Format: .txt)
#   - 19270430.txt (Format: .txt)
#   - 19270507.txt (Format: .txt)
#   - 19270514.txt (Format: .txt)
#   - 19270521.txt (Format: .txt)
#   - 19270528.txt (Format: .txt)
#   - 19270604.txt (Format: .txt)
#   - 19270611.txt (Format: .txt)
#   - 19270618.txt (Format: .txt)
#   - 19270625.txt (Format: .txt)
#   - 19270702.txt (Format: .txt)
#   - 19270709.txt (Format: .txt)
#   - 19270716.txt (Format: .txt)
#   - 19270723.txt (Format: .txt)
#   - 19270730.txt (Format: .txt)
#   - 19270806.txt (Format: .txt)
#   - 19270813.txt (Format: .txt)
#   - 19270820.txt (Format: .txt)
#   - 19270827.txt (Format: .txt)
#   - 19270903.txt (Format: .txt)
#   - 19270910.txt (Format: .txt)
#   - 19270917.txt (Format: .txt)
#   - 19270924.txt (Format: .txt)
#   - 19271001.txt (Format: .txt)
#   - 19271008.txt (Format: .txt)
#   - 19271015.txt (Format: .txt)
#   - 19271022.txt (Format: .txt)
#   - 19271029.txt (Format: .txt)
#   - 19271105.txt (Format: .txt)
#   - 19271112.txt (Format: .txt)
#   - 19271119.txt (Format: .txt)
#   - 19271126.txt (Format: .txt)
#   - 19271203.txt (Format: .txt)
#   - 19271210.txt (Format: .txt)
#   - 19271217.txt (Format: .txt)
#   - 19271224.txt (Format: .txt)
#   - 19271231.txt (Format: .txt)
#   - 19280107.txt (Format: .txt)
#   - 19280114.txt (Format: .txt)
#   - 19280121.txt (Format: .txt)
#   - 19280128.txt (Format: .txt)
#   - 19280204.txt (Format: .txt)
#   - 19280211.txt (Format: .txt)
#   - 19280218.txt (Format: .txt)
#   - 19280225.txt (Format: .txt)
#   - 19280303.txt (Format: .txt)
#   - 19280310.txt (Format: .txt)
#   - 19280317.txt (Format: .txt)
#   - 19280324.txt (Format: .txt)
#   - 19280331.txt (Format: .txt)
#   - 19280407.txt (Format: .txt)
#   - 19280414.txt (Format: .txt)
#   - 19280421.txt (Format: .txt)
#   - 19280428.txt (Format: .txt)
#   - 19280505.txt (Format: .txt)
#   - 19280512.txt (Format: .txt)
#   - 19280519.txt (Format: .txt)
#   - 19280526.txt (Format: .txt)
#   - 19280602.txt (Format: .txt)
#   - 19280609.txt (Format: .txt)
#   - 19280616.txt (Format: .txt)
#   - 19280623.txt (Format: .txt)
#   - 19280630.txt (Format: .txt)
#   - 19280707.txt (Format: .txt)
#   - 19280714.txt (Format: .txt)
#   - 19280721.txt (Format: .txt)
#   - 19280728.txt (Format: .txt)
#   - 19280804.txt (Format: .txt)
#   - 19280811.txt (Format: .txt)
#   - 19280818.txt (Format: .txt)
#   - 19280825.txt (Format: .txt)
#   - 19280901.txt (Format: .txt)
#   - 19280908.txt (Format: .txt)
#   - 19280922.txt (Format: .txt)
#   - 19280929.txt (Format: .txt)
#   - 19281006.txt (Format: .txt)
#   - 19281013.txt (Format: .txt)
#   - 19281020.txt (Format: .txt)
#   - 19281027.txt (Format: .txt)
#   - 19281103.txt (Format: .txt)
#   - 19281110.txt (Format: .txt)
#   - 19281117.txt (Format: .txt)
#   - 19281124.txt (Format: .txt)
#   - 19281201.txt (Format: .txt)
#   - 19281208.txt (Format: .txt)
#   - 19281215.txt (Format: .txt)
#   - 19281222.txt (Format: .txt)
#   - 19281229.txt (Format: .txt)
#   - 19290105.txt (Format: .txt)
#   - 19290112.txt (Format: .txt)
#   - 19290119.txt (Format: .txt)
#   - 19290126.txt (Format: .txt)
#   - 19290202.txt (Format: .txt)
#   - 19290209.txt (Format: .txt)
#   - 19290216.txt (Format: .txt)
#   - 19290223.txt (Format: .txt)
#   - 19290302.txt (Format: .txt)
#   - 19290309.txt (Format: .txt)
#   - 19290316.txt (Format: .txt)
#   - 19290323.txt (Format: .txt)
#   - 19290330.txt (Format: .txt)
#   - 19290406.txt (Format: .txt)
#   - 19290413.txt (Format: .txt)
#   - 19290420.txt (Format: .txt)
#   - 19290427.txt (Format: .txt)
#   - 19290504.txt (Format: .txt)
#   - 19290511.txt (Format: .txt)
#   - 19290518.txt (Format: .txt)
#   - 19290525.txt (Format: .txt)
#   - 19290601.txt (Format: .txt)
#   - 19290608.txt (Format: .txt)
#   - 19290615.txt (Format: .txt)
#   - 19290622.txt (Format: .txt)
#   - 19290629.txt (Format: .txt)
#   - 19290706.txt (Format: .txt)
#   - 19290713.txt (Format: .txt)
#   - 19290720.txt (Format: .txt)
#   - 19290727.txt (Format: .txt)
#   - 19290803.txt (Format: .txt)
#   - 19290810.txt (Format: .txt)
#   - 19290817.txt (Format: .txt)
#   - 19290824.txt (Format: .txt)
#   - 19290831.txt (Format: .txt)
#   - 19290907.txt (Format: .txt)
#   - 19290914.txt (Format: .txt)
#   - 19290921.txt (Format: .txt)
#   - 19290928.txt (Format: .txt)
#   - 19291005.txt (Format: .txt)
#   - 19291019.txt (Format: .txt)
#   - 19291026.txt (Format: .txt)
#   - 19291102.txt (Format: .txt)
#   - 19291109.txt (Format: .txt)
#   - 19291116.txt (Format: .txt)
#   - 19291123.txt (Format: .txt)
#   - 19291130.txt (Format: .txt)
#   - 19291207.txt (Format: .txt)
#   - 19291214.txt (Format: .txt)
#   - 19291221.txt (Format: .txt)
#   - 19291228.txt (Format: .txt)
#   - 19450106.txt (Format: .txt)
#   - 19450113.txt (Format: .txt)
#   - 19450120.txt (Format: .txt)
#   - 19450127.txt (Format: .txt)
#   - 19450203.txt (Format: .txt)
#   - 19450210.txt (Format: .txt)
#   - 19450217.txt (Format: .txt)
#   - 19450224.txt (Format: .txt)
#   - 19450303.txt (Format: .txt)
#   - 19450310.txt (Format: .txt)
#   - 19450317.txt (Format: .txt)
#   - 19450324.txt (Format: .txt)
#   - 19450331.txt (Format: .txt)
#   - 19450407.txt (Format: .txt)
#   - 19450414.txt (Format: .txt)
#   - 19450421.txt (Format: .txt)
#   - 19450428.txt (Format: .txt)
#   - 19450505.txt (Format: .txt)
#   - 19450512.txt (Format: .txt)
#   - 19450519.txt (Format: .txt)
#   - 19450526.txt (Format: .txt)
#   - 19450602.txt (Format: .txt)
#   - 19450609.txt (Format: .txt)
#   - 19450616.txt (Format: .txt)
#   - 19450623.txt (Format: .txt)
#   - 19450630.txt (Format: .txt)
#   - 19450707.txt (Format: .txt)
#   - 19450714.txt (Format: .txt)
#   - 19450721.txt (Format: .txt)
#   - 19450728.txt (Format: .txt)
#   - 19450804.txt (Format: .txt)
#   - 19450811.txt (Format: .txt)
#   - 19450818.txt (Format: .txt)
#   - 19450825.txt (Format: .txt)
#   - 19450901.txt (Format: .txt)
#   - 19450908.txt (Format: .txt)
#   - 19450915.txt (Format: .txt)
#   - 19450922.txt (Format: .txt)
#   - 19450929.txt (Format: .txt)
#   - 19451006.txt (Format: .txt)
#   - 19451013.txt (Format: .txt)
#   - 19451020.txt (Format: .txt)
#   - 19451027.txt (Format: .txt)
#   - 19451103.txt (Format: .txt)
#   - 19451110.txt (Format: .txt)
#   - 19451117.txt (Format: .txt)
#   - 19451124.txt (Format: .txt)
#   - 19451201.txt (Format: .txt)
#   - 19451208.txt (Format: .txt)
#   - 19451215.txt (Format: .txt)
#   - 19451222.txt (Format: .txt)
#   - 19451229.txt (Format: .txt)
#   - 19460105.txt (Format: .txt)
#   - 19460112.txt (Format: .txt)
#   - 19460119.txt (Format: .txt)
#   - 19460126.txt (Format: .txt)
#   - 19460202.txt (Format: .txt)
#   - 19460209.txt (Format: .txt)
#   - 19460216.txt (Format: .txt)
#   - 19460223.txt (Format: .txt)
#   - 19460302.txt (Format: .txt)
#   - 19460309.txt (Format: .txt)
#   - 19460316.txt (Format: .txt)
#   - 19460323.txt (Format: .txt)
#   - 19460330.txt (Format: .txt)
#   - 19460406.txt (Format: .txt)
#   - 19460413.txt (Format: .txt)
#   - 19460420.txt (Format: .txt)
#   - 19460427.txt (Format: .txt)
#   - 19460504.txt (Format: .txt)
#   - 19460511.txt (Format: .txt)
#   - 19460518.txt (Format: .txt)
#   - 19460525.txt (Format: .txt)
#   - 19460601.txt (Format: .txt)
#   - 19460608.txt (Format: .txt)
#   - 19460615.txt (Format: .txt)
#   - 19460622.txt (Format: .txt)
#   - 19460629.txt (Format: .txt)
#   - 19460706.txt (Format: .txt)
#   - 19460713.txt (Format: .txt)
#   - 19460720.txt (Format: .txt)
#   - 19460727.txt (Format: .txt)
#   - 19460803.txt (Format: .txt)
#   - 19460810.txt (Format: .txt)
#   - 19460817.txt (Format: .txt)
#   - 19460824.txt (Format: .txt)
#   - 19460831.txt (Format: .txt)
#   - 19460907.txt (Format: .txt)
#   - 19460914.txt (Format: .txt)
#   - 19460921.txt (Format: .txt)
#   - 19460928.txt (Format: .txt)
#   - 19461005.txt (Format: .txt)
#   - 19461012.txt (Format: .txt)
#   - 19461019.txt (Format: .txt)
#   - 19461026.txt (Format: .txt)
#   - 19461102.txt (Format: .txt)
#   - 19461109.txt (Format: .txt)
#   - 19461116.txt (Format: .txt)
#   - 19461123.txt (Format: .txt)
#   - 19461130.txt (Format: .txt)
#   - 19461207.txt (Format: .txt)
#   - 19461214.txt (Format: .txt)
#   - 19461221.txt (Format: .txt)
#   - 19461228.txt (Format: .txt)
#   - 19470104.txt (Format: .txt)
#   - 19470111.txt (Format: .txt)
#   - 19470118.txt (Format: .txt)
#   - 19470125.txt (Format: .txt)
#   - 19470201.txt (Format: .txt)
#   - 19470208.txt (Format: .txt)
#   - 19470215.txt (Format: .txt)
#   - 19470222.txt (Format: .txt)
#   - 19470301.txt (Format: .txt)
# ...
#   - jesús_izcoa_moure_bridge.txt (Format: .txt)
#   - jesús_t._piñero_house.txt (Format: .txt)
#   - jobos_beach.txt (Format: .txt)
#   - jose_v._toledo_federal_building_and_united_states_courthouse.txt (Format: .txt)
#   - josé_celso_barbosa.txt (Format: .txt)
#   - josé_miguel_agrelot_coliseum.txt (Format: .txt)
#   - joyuda,_puerto_rico.txt (Format: .txt)
#   - joyuda_lagoon.txt (Format: .txt)
#   - juana_díaz_barrio-pueblo.txt (Format: .txt)
#   - juan_boria.txt (Format: .txt)
#   - juan_ramón_loubriel_stadium.txt (Format: .txt)
#   - julia_de_burgos.txt (Format: .txt)
#   - julio_enrique_monagas_park.txt (Format: .txt)
#   - juncos_barrio-pueblo.txt (Format: .txt)
#   - lago_dos_bocas.txt (Format: .txt)
#   - laguna_cartagena_national_wildlife_refuge.txt (Format: .txt)
#   - lajas_barrio-pueblo.txt (Format: .txt)
#   - lake_luchetti.txt (Format: .txt)
#   - lares_barrio-pueblo.txt (Format: .txt)
#   - lares_ice_cream_parlor.txt (Format: .txt)
#   - las_cabañas_bridge.txt (Format: .txt)
#   - las_cascadas_water_park.txt (Format: .txt)
#   - las_catalinas_mall.txt (Format: .txt)
#   - las_marías_barrio-pueblo.txt (Format: .txt)
#   - las_piedras_barrio-pueblo.txt (Format: .txt)
#   - la_bombonera_(san_juan).txt (Format: .txt)
#   - la_concha_renaissance_san_juan_resort.txt (Format: .txt)
#   - la_cordillera_reef_nature_reserve.txt (Format: .txt)
#   - la_fortaleza.txt (Format: .txt)
#   - la_giralda_(san_juan,_puerto_rico).txt (Format: .txt)
#   - la_guancha_(ponce,_puerto_rico).txt (Format: .txt)
#   - la_liendre_bridge.txt (Format: .txt)
#   - la_mallorquina.txt (Format: .txt)
#   - la_parguera.txt (Format: .txt)
#   - la_perla,_san_juan,_puerto_rico.txt (Format: .txt)
#   - la_placita_de_santurce.txt (Format: .txt)
#   - la_plata_lake.txt (Format: .txt)
#   - la_pocita_de_las_golondrinas_beach.txt (Format: .txt)
#   - la_ventana_al_mar.txt (Format: .txt)
#   - lechon.txt (Format: .txt)
#   - legend_of_diego_salcedo.txt (Format: .txt)
#   - letras_de_ponce.txt (Format: .txt)
#   - lin-manuel_miranda.txt (Format: .txt)
#   - logia_masónica_hijos_de_la_luz.txt (Format: .txt)
#   - los_chinos_de_ponce.txt (Format: .txt)
#   - los_morrillos_lighthouse.txt (Format: .txt)
#   - los_tres_picachos.txt (Format: .txt)
#   - los_tres_picachos_state_forest.txt (Format: .txt)
#   - los_túneles_subterráneos_de_san_germán.txt (Format: .txt)
#   - loverbar.txt (Format: .txt)
#   - loíza_barrio-pueblo.txt (Format: .txt)
#   - loíza_lake.txt (Format: .txt)
#   - luis_a._ferré_performing_arts_center.txt (Format: .txt)
#   - luis_a._ferré_united_states_courthouse_and_post_office_building.txt (Format: .txt)
#   - luis_muñoz_marín_international_airport.txt (Format: .txt)
#   - luis_muñoz_marín_park.txt (Format: .txt)
#   - luis_muñoz_rivera_park.txt (Format: .txt)
#   - luquillo_barrio-pueblo.txt (Format: .txt)
#   - luquillo_beach.txt (Format: .txt)
#   - línea_avanzada.txt (Format: .txt)
#   - lópez_residence.txt (Format: .txt)
#   - manatí_barrio-pueblo.txt (Format: .txt)
#   - manatí_bridge_at_mata_de_plátano.txt (Format: .txt)
#   - maricao_barrio-pueblo.txt (Format: .txt)
#   - maricao_fish_hatchery.txt (Format: .txt)
#   - maricao_state_forest.txt (Format: .txt)
#   - mario_morales_coliseum.txt (Format: .txt)
#   - martín_peña_bridge.txt (Format: .txt)
#   - mar_bella_beach.txt (Format: .txt)
#   - maunabo_barrio-pueblo.txt (Format: .txt)
#   - mavilla_bridge.txt (Format: .txt)
#   - mayagüez_barrio-pueblo.txt (Format: .txt)
#   - mayagüez_city_hall.txt (Format: .txt)
#   - mayagüez_resort_&_casino.txt (Format: .txt)
#   - mccabe_memorial_church.txt (Format: .txt)
#   - miramar_(santurce).txt (Format: .txt)
#   - mizpa_pentecostal_university.txt (Format: .txt)
#   - moca_barrio-pueblo.txt (Format: .txt)
#   - mona_ground_iguana.txt (Format: .txt)
#   - monte_jayuya.txt (Format: .txt)
#   - monumento_al_jíbaro_puertorriqueño.txt (Format: .txt)
#   - monumento_a_la_abolición_de_la_exclavitud.txt (Format: .txt)
#   - monumento_a_los_heroes_de_el_polvorín_(obelisk).txt (Format: .txt)
#   - monumento_a_los_heroes_de_el_polvorín_(tomb).txt (Format: .txt)
#   - morovis_barrio-pueblo.txt (Format: .txt)
#   - morovis_national_cemetery.txt (Format: .txt)
#   - morrillito.txt (Format: .txt)
#   - museo_castillo_serrallés.txt (Format: .txt)
#   - museo_del_autonomismo_puertorriqueño.txt (Format: .txt)
#   - museo_de_arte_de_ponce.txt (Format: .txt)
#   - museo_de_la_arquitectura_ponceña.txt (Format: .txt)
#   - museo_de_la_historia_de_ponce.txt (Format: .txt)
#   - museo_de_la_masacre_de_ponce.txt (Format: .txt)
#   - museo_de_la_música_puertorriqueña.txt (Format: .txt)
#   - museo_de_vida_silvestre.txt (Format: .txt)
#   - museum_of_art_of_puerto_rico.txt (Format: .txt)
#   - museum_of_transportation_of_puerto_rico.txt (Format: .txt)
#   - naguabo_barrio-pueblo.txt (Format: .txt)
#   - naranjito_barrio-pueblo.txt (Format: .txt)
#   - normandie_hotel.txt (Format: .txt)
#   - nuestra_señora_de_lourdes_chapel.txt (Format: .txt)
#   - nuevo_milenio_state_forest.txt (Format: .txt)
#   - ocean_park_(santurce).txt (Format: .txt)
#   - old_piedras_river_aqueduct.txt (Format: .txt)
#   - old_san_juan.txt (Format: .txt)
#   - orocovis.txt (Format: .txt)
#   - orocovis_barrio-pueblo.txt (Format: .txt)
#   - orthodox_judaism.txt (Format: .txt)
#   - our_lady_of_lourdes.txt (Format: .txt)
#   - pablo_casals_museum.txt (Format: .txt)
#   - palacete_los_moreau.txt (Format: .txt)
#   - palmas_del_mar.txt (Format: .txt)
#   - panteón_nacional_román_baldorioty_de_castro.txt (Format: .txt)
#   - parque_del_litoral.txt (Format: .txt)
#   - parque_del_retiro.txt (Format: .txt)
#   - parque_del_tricentenario_(ponce,_puerto_rico).txt (Format: .txt)
#   - parque_de_bombas.txt (Format: .txt)
#   - parque_de_bombas_maximiliano_merced.txt (Format: .txt)
#   - parque_de_las_ciencias.txt (Format: .txt)
#   - parque_de_la_abolición.txt (Format: .txt)
#   - parque_de_la_ceiba.txt (Format: .txt)
#   - parque_ecológico_urbano.txt (Format: .txt)
#   - parque_familiar_julio_enrique_monagas.txt (Format: .txt)
#   - parque_lineal_veredas_del_labrador.txt (Format: .txt)
#   - parque_luis_a._wito_morales.txt (Format: .txt)
#   - parque_nacional_de_las_cavernas_del_río_camuy.txt (Format: .txt)
#   - parque_pedro_albizu_campos.txt (Format: .txt)
#   - parque_urbano_dora_colón_clavell.txt (Format: .txt)
#   - parroquia_del_espíritu_santo_y_san_patricio.txt (Format: .txt)
#   - paseo_atocha.txt (Format: .txt)
#   - paseo_de_la_princesa.txt (Format: .txt)
#   - paseo_tablado_la_guancha.txt (Format: .txt)
#   - paseo_víctor_rojas.txt (Format: .txt)
#   - patillas_barrio-pueblo.txt (Format: .txt)
#   - peñuelas_barrio-pueblo.txt (Format: .txt)
#   - pico_piedra.txt (Format: .txt)
#   - pico_rodadero.txt (Format: .txt)
#   - picó_pomar_residence.txt (Format: .txt)
#   - piñones_state_forest.txt (Format: .txt)
#   - playa_espinar.txt (Format: .txt)
#   - playita_del_condado.txt (Format: .txt)
#   - plaza_carolina.txt (Format: .txt)
#   - plaza_colón.txt (Format: .txt)
#   - plaza_colón_(san_juan).txt (Format: .txt)
#   - plaza_degetau.txt (Format: .txt)
#   - plaza_del_caribe.txt (Format: .txt)
#   - plaza_del_mercado_de_ponce.txt (Format: .txt)
#   - plaza_del_norte.txt (Format: .txt)
#   - plaza_del_quinto_centenario.txt (Format: .txt)
#   - plaza_del_sol_(puerto_rico).txt (Format: .txt)
#   - plaza_de_armas,_san_juan.txt (Format: .txt)
#   - plaza_de_la_catedral_(san_juan).txt (Format: .txt)
#   - plaza_de_san_josé.txt (Format: .txt)
#   - plaza_juan_ponce_de_león.txt (Format: .txt)
#   - plaza_las_américas_(puerto_rico).txt (Format: .txt)
#   - plaza_las_delicias.txt (Format: .txt)
#   - plaza_muñoz_rivera.txt (Format: .txt)
#   - plaza_rio_hondo.txt (Format: .txt)
#   - polvorín_de_miraflores.txt (Format: .txt)
#   - polytechnic_university_of_puerto_rico.txt (Format: .txt)
#   - ponce_cement,_inc..txt (Format: .txt)
#   - ponce_city_hall.txt (Format: .txt)
#   - ponce_high_school.txt (Format: .txt)
#   - ponce_historic_zone.txt (Format: .txt)
#   - ponce_school_of_medicine.txt (Format: .txt)
#   - ponce_ymca_building.txt (Format: .txt)
#   - pontificia_universidad_católica_de_puerto_rico.txt (Format: .txt)
#   - porta_coeli_(puerto_rico).txt (Format: .txt)
#   - pozo_de_jacinto.txt (Format: .txt)
#   - primera_iglesia_bautista_de_caguas.txt (Format: .txt)
#   - primera_iglesia_metodista_unida_de_ponce.txt (Format: .txt)
#   - pueblo,_san_juan,_puerto_rico.txt (Format: .txt)
#   - puente_blanco.txt (Format: .txt)
#   - puente_de_coloso.txt (Format: .txt)
#   - puente_de_las_calabazas.txt (Format: .txt)
#   - puente_no._6.txt (Format: .txt)
#   - puerta_de_tierra,_san_juan.txt (Format: .txt)
#   - puerto_del_rey_marina.txt (Format: .txt)
#   - puerto_rico.txt (Format: .txt)
#   - puerto_rico_convention_center.txt (Format: .txt)
#   - puerto_rico_iron_works.txt (Format: .txt)
#   - puerto_rico_museum_of_contemporary_art.txt (Format: .txt)
#   - puerto_rico_national_library.txt (Format: .txt)
#   - punta_borinquen_light.txt (Format: .txt)
#   - punta_de_las_figuras_light.txt (Format: .txt)
#   - punta_higuero_light.txt (Format: .txt)
#   - punta_mulas_light.txt (Format: .txt)
#   - punta_santiago,_humacao,_puerto_rico.txt (Format: .txt)
#   - punta_tuna_light.txt (Format: .txt)
#   - quebradillas_barrio-pueblo.txt (Format: .txt)
#   - rafael_hernández_marín.txt (Format: .txt)
#   - ramón_rivero_(diplo).txt (Format: .txt)
#   - residencia_aboy-lompré.txt (Format: .txt)
#   - residencia_armstrong-poventud.txt (Format: .txt)
#   - residencia_rosaly-batiz.txt (Format: .txt)
#   - residencia_subirá.txt (Format: .txt)
#   - rincón_barrio-pueblo.txt (Format: .txt)
#   - roberto_clemente_coliseum.txt (Format: .txt)
#   - roberto_clemente_stadium.txt (Format: .txt)
#   - roosevelt_roads_naval_station.txt (Format: .txt)
#   - rovira_biscuits_corporation.txt (Format: .txt)
#   - rum.txt (Format: .txt)
#   - rum_planetarium.txt (Format: .txt)
#   - río_abajo_state_forest.txt (Format: .txt)
#   - río_grande_barrio-pueblo.txt (Format: .txt)
#   - río_grande_de_loíza.txt (Format: .txt)
#   - río_matón_bridge.txt (Format: .txt)
#   - río_piedras_bridge.txt (Format: .txt)
#   - sabana_grande_barrio-pueblo.txt (Format: .txt)
#   - sabana_grande_masonic_cemetery.txt (Format: .txt)
#   - saint_john's_school_(san_juan).txt (Format: .txt)
#   - saliente_river.txt (Format: .txt)
#   - salinas_barrio-pueblo.txt (Format: .txt)
#   - samuel_morse.txt (Format: .txt)
#   - santa_ana_church_(san_juan).txt (Format: .txt)
#   - santa_isabel_barrio-pueblo.txt (Format: .txt)
#   - santa_maría_magdalena_de_pazzis_cemetery.txt (Format: .txt)
#   - santurce,_san_juan,_puerto_rico.txt (Format: .txt)
#   - san_cristóbal_canyon.txt (Format: .txt)
#   - san_germán_historic_district.txt (Format: .txt)
#   - san_josé_church.txt (Format: .txt)
#   - san_juan_botanical_garden.txt (Format: .txt)
#   - san_juan_city_hall.txt (Format: .txt)
#   - san_juan_marriott_resort_&_stellaris_casino.txt (Format: .txt)
#   - san_juan_natatorium.txt (Format: .txt)
#   - san_juan_puerto_rico_temple.txt (Format: .txt)
#   - san_lorenzo_barrio-pueblo.txt (Format: .txt)
#   - san_miguel_arcángel_church_(cabo_rojo).txt (Format: .txt)
#   - san_patricio_plaza.txt (Format: .txt)
#   - san_patricio_state_forest.txt (Format: .txt)
#   - san_sebastián_barrio-pueblo.txt (Format: .txt)
#   - school_of_tropical_medicine_(puerto_rico).txt (Format: .txt)
#   - sixto_escobar.txt (Format: .txt)
#   - stud_farm.txt (Format: .txt)
#   - supreme_court_building_(puerto_rico).txt (Format: .txt)
#   - susúa_state_forest.txt (Format: .txt)
#   - t-mobile_district.txt (Format: .txt)
#   - teatro_fox_delicias.txt (Format: .txt)
#   - teatro_la_perla.txt (Format: .txt)
#   - teatro_tapia.txt (Format: .txt)
#   - teatro_yagüez.txt (Format: .txt)
#   - teodoro_moscoso_bridge.txt (Format: .txt)
#   - the_mall_of_san_juan.txt (Format: .txt)
#   - tito_puente_amphitheatre.txt (Format: .txt)
#   - toa_alta_barrio-pueblo.txt (Format: .txt)
#   - toa_baja_barrio-pueblo.txt (Format: .txt)
#   - toro_negro_state_forest.txt (Format: .txt)
#   - tortuguero_lagoon.txt (Format: .txt)
#   - train_of_the_south.txt (Format: .txt)
#   - trujillo_alto_barrio-pueblo.txt (Format: .txt)
#   - u.s._custom_house_(san_juan,_puerto_rico).txt (Format: .txt)
#   - u.s._post_office_and_courthouse_(mayagüez,_puerto_rico).txt (Format: .txt)
#   - united_states_customs_house_(fajardo,_puerto_rico).txt (Format: .txt)
#   - united_states_customs_house_(ponce,_puerto_rico).txt (Format: .txt)
#   - united_states_district_court_for_the_district_of_puerto_rico.txt (Format: .txt)
#   - universidad_del_sagrado_corazón.txt (Format: .txt)
#   - university_gardens_high_school.txt (Format: .txt)
#   - university_high_school_(san_juan).txt (Format: .txt)
#   - university_of_puerto_rico,_medical_sciences_campus.txt (Format: .txt)
#   - university_of_puerto_rico,_río_piedras_campus.txt (Format: .txt)
#   - university_of_puerto_rico_at_cayey.txt (Format: .txt)
#   - university_of_puerto_rico_at_humacao.txt (Format: .txt)
#   - university_of_puerto_rico_at_mayagüez.txt (Format: .txt)
#   - university_of_puerto_rico_at_ponce.txt (Format: .txt)
#   - university_of_puerto_rico_school_of_medicine.txt (Format: .txt)
#   - uss_killen_(dd-593).txt (Format: .txt)
#   - utuado_barrio-pueblo.txt (Format: .txt)
#   - vega_alta_barrio-pueblo.txt (Format: .txt)
#   - vega_baja_barrio-pueblo.txt (Format: .txt)
#   - vega_state_forest.txt (Format: .txt)
#   - vieques_national_wildlife_refuge.txt (Format: .txt)
#   - villalba,_puerto_rico.txt (Format: .txt)
#   - villalba_barrio-pueblo.txt (Format: .txt)
#   - villa_pesquera.txt (Format: .txt)
#   - west_indian_manatee.txt (Format: .txt)
#   - whale_watching.txt (Format: .txt)
#   - william_miranda_marín_botanical_and_cultural_garden.txt (Format: .txt)
#   - world_war_ii.txt (Format: .txt)
#   - yabucoa_barrio-pueblo.txt (Format: .txt)
#   - yauco_barrio-pueblo.txt (Format: .txt)
#   - zona_historica_de_ponce.txt (Format: .txt)
# Files in municipalities:
# Total files: 78
#   - Adjuntas.txt (Format: .txt)
#   - Aguada.txt (Format: .txt)
#   - Aguadilla.txt (Format: .txt)
#   - Aguas Buenas.txt (Format: .txt)
#   - Aibonito.txt (Format: .txt)
#   - Arecibo.txt (Format: .txt)
#   - Arroyo.txt (Format: .txt)
#   - Añasco.txt (Format: .txt)
#   - Barceloneta.txt (Format: .txt)
#   - Barranquitas.txt (Format: .txt)
#   - Bayamón.txt (Format: .txt)
#   - Cabo Rojo.txt (Format: .txt)
#   - Caguas.txt (Format: .txt)
#   - Camuy.txt (Format: .txt)
#   - Canóvanas.txt (Format: .txt)
#   - Carolina.txt (Format: .txt)
#   - Cataño.txt (Format: .txt)
#   - Cayey.txt (Format: .txt)
#   - Ceiba.txt (Format: .txt)
#   - Ciales.txt (Format: .txt)
#   - Cidra.txt (Format: .txt)
#   - Coamo.txt (Format: .txt)
#   - Comerío.txt (Format: .txt)
#   - Corozal.txt (Format: .txt)
#   - Culebra.txt (Format: .txt)
#   - Dorado.txt (Format: .txt)
#   - Fajardo.txt (Format: .txt)
#   - Florida.txt (Format: .txt)
#   - Guayama.txt (Format: .txt)
#   - Guayanilla.txt (Format: .txt)
#   - Guaynabo.txt (Format: .txt)
#   - Gurabo.txt (Format: .txt)
#   - Guánica.txt (Format: .txt)
#   - Hatillo.txt (Format: .txt)
#   - Hormigueros.txt (Format: .txt)
#   - Humacao.txt (Format: .txt)
#   - Isabela.txt (Format: .txt)
#   - Jayuya.txt (Format: .txt)
#   - Juana Díaz.txt (Format: .txt)
#   - Juncos.txt (Format: .txt)
#   - Lajas.txt (Format: .txt)
#   - Lares.txt (Format: .txt)
#   - Las Marías.txt (Format: .txt)
#   - Las Piedras.txt (Format: .txt)
#   - Loíza.txt (Format: .txt)
#   - Luquillo.txt (Format: .txt)
#   - Manatí.txt (Format: .txt)
#   - Maricao.txt (Format: .txt)
#   - Maunabo.txt (Format: .txt)
#   - Mayagüez.txt (Format: .txt)
#   - Moca.txt (Format: .txt)
#   - Morovis.txt (Format: .txt)
#   - Naguabo.txt (Format: .txt)
#   - Naranjito.txt (Format: .txt)
#   - Orocovis.txt (Format: .txt)
#   - Patillas.txt (Format: .txt)
#   - Peñuelas.txt (Format: .txt)
#   - Ponce.txt (Format: .txt)
#   - Quebradillas.txt (Format: .txt)
#   - Rincón.txt (Format: .txt)
#   - Río Grande.txt (Format: .txt)
#   - Sabana Grande.txt (Format: .txt)
#   - Salinas.txt (Format: .txt)
#   - San Germán.txt (Format: .txt)
#   - San Juan.txt (Format: .txt)
#   - San Lorenzo.txt (Format: .txt)
#   - San Sebastián.txt (Format: .txt)
#   - Santa Isabel.txt (Format: .txt)
#   - Toa Alta.txt (Format: .txt)
#   - Toa Baja.txt (Format: .txt)
#   - Trujillo Alto.txt (Format: .txt)
#   - Utuado.txt (Format: .txt)
#   - Vega Alta.txt (Format: .txt)
#   - Vega Baja.txt (Format: .txt)
#   - Vieques.txt (Format: .txt)
#   - Villalba.txt (Format: .txt)
#   - Yabucoa.txt (Format: .txt)
#   - Yauco.txt (Format: .txt)

# %% [markdown]
# ### Files Duplicados de news = 822
#
# Por el momento son los files duplicados de (data/elmundo_chunked_es_page1_15years) y (data/elmundo_chunked_es_page1_40years), que se repiten files en español o están vacios

# %%
import os
import hashlib

def get_file_hash(file_path):
    hasher = hashlib.md5()
    with open(file_path, 'rb') as f:
        buf = f.read()
        hasher.update(buf)
    return hasher.hexdigest()

def list_files_with_hashes(base_directory, subdirectories):
    file_hashes = {}
    
    for subdirectory in subdirectories:
        full_path = os.path.join(base_directory, subdirectory)
        if os.path.exists(full_path):
            for root, dirs, files in os.walk(full_path):
                for file in files:
                    if not file.endswith('.zip'):
                        file_path = os.path.join(root, file)
                        file_hash = get_file_hash(file_path)
                        if file_hash in file_hashes:
                            file_hashes[file_hash].append(file_path)
                        else:
                            file_hashes[file_hash] = [file_path]
    
    return file_hashes

base_directory = 'data'
subdirectories = [
    'elmundo_chunked_en_page1_15years',
    'elmundo_chunked_es_page1_15years',
    'elmundo_chunked_es_page1_40years'
]

file_hashes = list_files_with_hashes(base_directory, subdirectories)

duplicate_files = {hash: paths for hash, paths in file_hashes.items() if len(paths) > 1}

print(f'Total identical files: {len(duplicate_files)}')
for file_hash, paths in duplicate_files.items():
    print(f'Hash: {file_hash}')
    for path in paths:
        print(f'  - {path}')
# Out:
# Total identical files: 822
# Hash: 57dcfd0990d309566071c648f9b53a33
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200103.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200103_1.txt
# Hash: 8cff3c1b7a97bd1498fe2d0160fede41
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200110.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200110_1.txt
# Hash: 92dcfa5e31ce4fd377e6ec24c5729f98
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200117.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200117_1.txt
# Hash: 7e8af8c03d6b67e2c138958a10620bcb
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200124.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200124_1.txt
# Hash: c3857bf83654efcee9c112c8bf0c12c8
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200131.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200131_1.txt
# Hash: a7cb06d3fcd628dcc2c761a25cd738f8
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200207.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200207_1.txt
# Hash: af8b15a58d2bec6bc42a98ffdb3c873c
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200214.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200214_1.txt
# Hash: e49df494cb8b4e23dfd43dfa1adbac4c
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200221.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200221_1.txt
# Hash: 7de8b918a8d20bdebabbf400ff5f56b5
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200228.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200228_1.txt
# Hash: 124e37fe7315eb35200ad782581ef33f
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200306.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19200306_1.txt
# Hash: c0b400801bb1c7ba580264237e757139
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19200313.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501014.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501014_1.txt
# Hash: 423a2133bbd833a2c63edc7d731cbe9a
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501021.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501021_1.txt
# Hash: 827505004ac1fc7b7310c43103465d49
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501028.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501028_1.txt
# Hash: 6a11642db518e55e3d6c0de49b26a65c
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501104.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501104_1.txt
# Hash: 7e2652a4043385ae5ef5976653ceb05e
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501111.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501111_1.txt
# Hash: 5a5955bbbdfe37c57ddfe716e467b4c2
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501118.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501118_1.txt
# Hash: a04832100a20d180142d42bf25d1984d
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501125.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501125_1.txt
# Hash: 3d46bd49cc501c240c26b86b5bd62357
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501202.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501202_1.txt
# Hash: 9bd0a1a137680f91278df6cfee16606a
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501209.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501209_1.txt
# Hash: 02335b9266c32b5da9e8f962255b5b8a
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501216.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501216_1.txt
# Hash: c0ba891417fa71bc979581966621bdba
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501223.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501223_1.txt
# Hash: 5de222eb48c2d172800ae9ceaa92297c
#   - data\elmundo_chunked_es_page1_15years\elmundo_chunked_es_page1_15years\19501230.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19501230_1.txt
# Hash: 0054411741e98c61e35b7ab04941bbad
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19380101_1.txt
#   - data\elmundo_chunked_es_page1_40years\elmundo_chunked_es_page1_40years\19410104_1.txt

# %% [markdown]
# ### Create a Data Repository for landmarks, municipalities, and news (3 el mundo chunked)

# %%
import os
import json

def read_files_in_directory(directory):
    data = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if not file.endswith('.zip'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    data.append({'file_name': file, 'content': content})
    return data

def extract_landmarks_data(data):
    # Placeholder for extracting landmarks data
    landmarks = []
    for item in data:
        # Extract relevant details from item['content']
        landmarks.append({'file_name': item['file_name'], 'details': item['content']})
    return landmarks

def extract_municipalities_data(data):
    # Placeholder for extracting municipalities data
    municipalities = []
    for item in data:
        # Extract relevant details from item['content']
        municipalities.append({'file_name': item['file_name'], 'details': item['content']})
    return municipalities

def extract_news_data(data):
    # Placeholder for extracting news data
    news = []
    for item in data:
        # Extract relevant details from item['content']
        news.append({'file_name': item['file_name'], 'details': item['content']})
    return news

base_directory = 'data'
directories = {
    'landmarks': 'landmarks',
    'municipalities': 'municipalities',
    'news': [
        'elmundo_chunked_en_page1_15years',
        'elmundo_chunked_es_page1_15years',
        'elmundo_chunked_es_page1_40years'
    ]
}

# Read and extract data from landmarks
landmarks_data = read_files_in_directory(os.path.join(base_directory, directories['landmarks']))
landmarks = extract_landmarks_data(landmarks_data)

# Read and extract data from municipalities
municipalities_data = read_files_in_directory(os.path.join(base_directory, directories['municipalities']))
municipalities = extract_municipalities_data(municipalities_data)

# Read and extract data from news
news_data = []
for news_dir in directories['news']:
    news_data.extend(read_files_in_directory(os.path.join(base_directory, news_dir)))
news = extract_news_data(news_data)

# Combine all data into a single repository
data_repository = {
    'landmarks': landmarks,
    'municipalities': municipalities,
    'news': news
}

# Save the data repository to a JSON file
with open('puerto_rico_data_repository.json', 'w', encoding='utf-8') as f:
    json.dump(data_repository, f, ensure_ascii=False, indent=4)

print('Data repository created successfully.')
# Out:
# Data repository created successfully.

# %% [markdown]
# puerto_rico_data_repository.json /// data repository

# %% [markdown]
# ** Extract Key Details: **  Use NLP techniques to extract relevant information from each file.
# Clean and Enhance Text Data: Process and clean the text data to ensure it is suitable for retrieval and generation.

# %%
import os
import json
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

# Download NLTK data files (only need to run once)
nltk.download('punkt')
nltk.download('stopwords')

##Reading the files in the directory
def read_files_in_directory(directory):
    data = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if not file.endswith('.zip'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    data.append({'file_name': file, 'content': content})
    return data

## Cleaning the text
def clean_text(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    filtered_text = [w for w in word_tokens if not w.lower() in stop_words]
    return ' '.join(filtered_text)


##Extracting the data from the landmarks
def extract_landmarks_data(data):
    landmarks = []
    for item in data:
        content = clean_text(item['content'])
        # Extract relevant details from content
        summary = ' '.join(sent_tokenize(content)[:2])  # Simple summary: first 2 sentences
        landmarks.append({'file_name': item['file_name'], 'summary': summary})
    return landmarks

##Extracting the data from the municipalities
def extract_municipalities_data(data):
    municipalities = []
    for item in data:
        content = clean_text(item['content'])
        # Extract relevant details from content
        summary = ' '.join(sent_tokenize(content)[:2])  # Simple summary: first 2 sentences
        municipalities.append({'file_name': item['file_name'], 'summary': summary})
    return municipalities

##Extracting the data from the news
def extract_news_data(data):
    news = []
    for item in data:
        content = clean_text(item['content'])
        # Extract relevant details from content
        summary = ' '.join(sent_tokenize(content)[:2])  # Simple summary: first 2 sentences
        news.append({'file_name': item['file_name'], 'summary': summary})
    return news

base_directory = 'data'
directories = {
    'landmarks': 'landmarks',
    'municipalities': 'municipalities',
    'news': [
        'elmundo_chunked_en_page1_15years',
        'elmundo_chunked_es_page1_15years',
        'elmundo_chunked_es_page1_40years'
    ]
}

# Read and extract data from landmarks
landmarks_data = read_files_in_directory(os.path.join(base_directory, directories['landmarks']))
landmarks = extract_landmarks_data(landmarks_data)

# Read and extract data from municipalities
municipalities_data = read_files_in_directory(os.path.join(base_directory, directories['municipalities']))
municipalities = extract_municipalities_data(municipalities_data)

# Read and extract data from news
news_data = []
for news_dir in directories['news']:
    news_data.extend(read_files_in_directory(os.path.join(base_directory, news_dir)))
news = extract_news_data(news_data)

# Combine all data into a single repository
data_repository = {
    'landmarks': landmarks,
    'municipalities': municipalities,
    'news': news
}

# Save the data repository to a JSON file
with open('puerto_rico_data_repository.json', 'w', encoding='utf-8') as f:
    json.dump(data_repository, f, ensure_ascii=False, indent=4)

print('Data repository created successfully.')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Latif-
# [nltk_data]     Calderón\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Latif-
# [nltk_data]     Calderón\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Data repository created successfully.

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

# Load the GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

def summarize_text(text):
    input_text = "summarize: " + text
    inputs = tokenizer.encode(input_text, return_tensors="pt", max_length=512, truncation=True)
    
    outputs = model.generate(inputs, max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    return summary

# %% [markdown]
# ### T5 Transformer : Hugging Face text summarization (NLP)

# %%
pip uninstall sentencepiece
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in c:\users\latif-calderón\anaconda3\lib\site-packages (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade transformers
# !pip install --upgrade torch
# Out:
# Collecting transformers
#   Downloading transformers-4.48.2-py3-none-any.whl.metadata (44 kB)
# Requirement already satisfied: filelock in c:\users\latif-calderón\anaconda33\lib\site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.24.0 (from transformers)
#   Downloading huggingface_hub-0.28.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\latif-calderón\anaconda33\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\latif-calderón\appdata\roaming\python\python312\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\latif-calderón\anaconda33\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\latif-calderón\anaconda33\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\latif-calderón\anaconda33\lib\site-packages (from transformers) (2.32.3)
# Collecting tokenizers<0.22,>=0.21 (from transformers)
#   Using cached tokenizers-0.21.0-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Using cached safetensors-0.5.2-cp38-abi3-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.27 in c:\users\latif-calderón\anaconda33\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\latif-calderón\anaconda33\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\latif-calderón\anaconda33\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: colorama in c:\users
5 MB/s eta 0:00:02
#    ---------------------------------- ---- 182.2/204.1 MB 21.4 MB/s eta 0:00:02
#    ---------------------------------- ---- 182.2/204.1 MB 21.4 MB/s eta 0:00:02
#    ----------------------------------- --- 183.5/204.1 MB 20.8 MB/s eta 0:00:01
#    ----------------------------------- --- 183.5/204.1 MB 20.8 MB/s eta 0:00:01
#    ----------------------------------- --- 184.5/204.1 MB 19.8 MB/s eta 0:00:01
#    ----------------------------------- --- 186.9/204.1 MB 19.6 MB/s eta 0:00:01
#    ----------------------------------- --- 187.2/204.1 MB 19.2 MB/s eta 0:00:01
#    ------------------------------------ -- 189.5/204.1 MB 19.3 MB/s eta 0:00:01
#    ------------------------------------ -- 190.6/204.1 MB 18.9 MB/s eta 0:00:01
#    ------------------------------------ -- 191.9/204.1 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------ -- 192.4/204.1 MB 18.4 MB/s eta 0:00:01
#    ------------------------------------ -- 192.9/204.1 MB 18.1 MB/s eta 0:00:01
#    ------------------------------------- - 194.5/204.1 MB 17.6 MB/s eta 0:00:01
#    ------------------------------------- - 195.6/204.1 MB 17.6 MB/s eta 0:00:01
#    ------------------------------------- - 195.6/204.1 MB 17.6 MB/s eta 0:00:01
#    ------------------------------------- - 196.9/204.1 MB 16.9 MB/s eta 0:00:01
#    ------------------------------------- - 197.4/204.1 MB 16.8 MB/s eta 0:00:01
#    ------------------------------------- - 197.9/204.1 MB 16.4 MB/s eta 0:00:01
#    ------------------------------------- - 198.7/204.1 MB 16.3 MB/s eta 0:00:01
#    ------------------------------------- - 198.7/204.1 MB 16.3 MB/s eta 0:00:01
#    ------------------------------------- - 198.7/204.1 MB 16.3 MB/s eta 0:00:01
#    ------------------------------------- - 198.7/204.1 MB 16.3 MB/s eta 0:00:01
#    --------------------------------------  199.0/204.1 MB 15.1 MB/s eta 0:00:01
#    --------------------------------------  199.0/204.1 MB 15.1 MB/s eta 0:00:01
#    --------------------------------------  199.0/204.1 MB 15.1 MB/s eta 0:00:01
#    --------------------------------------  199.2/204.1 MB 14.5 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  200.0/204.1 MB 14.3 MB/s eta 0:00:01
#    --------------------------------------  201.3/204.1 MB 11.8 MB/s eta 0:00:01
#    --------------------------------------  203.4/204.1 MB 11.7 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    --------------------------------------  203.9/204.1 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 204.1/204.1 MB 2.6 MB/s eta 0:00:00
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Installing collected packages: sympy, torch
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
# Successfully installed sympy-1.13.1 torch-2.6.0

# %%
import os
import json
from transformers import T5ForConditionalGeneration, T5Tokenizer

# Load the T5 model and tokenizer
model_name = "t5-small"
model = T5ForConditionalGeneration.from_pretrained(model_name)
tokenizer = T5Tokenizer.from_pretrained(model_name)

def read_files_in_directory(directory):
    data = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if not file.endswith('.zip'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    data.append({'file_name': file, 'content': content})
    return data

def summarize_text(text):
    # Preprocess the text for T5
    input_text = "summarize: " + text
    inputs = tokenizer.encode(input_text, return_tensors="pt", max_length=512, truncation=True)
    
    # Generate the summary
    summary_ids = model.generate(inputs, max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    
    return summary

def extract_landmarks_data(data):
    landmarks = []
    for item in data:
        summary = summarize_text(item['content'])
        landmarks.append({'file_name': item['file_name'], 'summary': summary})
    return landmarks

def extract_municipalities_data(data):
    municipalities = []
    for item in data:
        summary = summarize_text(item['content'])
        municipalities.append({'file_name': item['file_name'], 'summary': summary})
    return municipalities

def extract_news_data(data):
    news = []
    for item in data:
        summary = summarize_text(item['content'])
        news.append({'file_name': item['file_name'], 'summary': summary})
    return news

base_directory = 'data'
directories = {
    'landmarks': 'landmarks',
    'municipalities': 'municipalities',
    'news': [
        'elmundo_chunked_en_page1_15years',
        'elmundo_chunked_es_page1_15years',
        'elmundo_chunked_es_page1_40years'
    ]
}

# Read and extract data from landmarks
landmarks_data = read_files_in_directory(os.path.join(base_directory, directories['landmarks']))
landmarks = extract_landmarks_data(landmarks_data)

# Read and extract data from municipalities
municipalities_data = read_files_in_directory(os.path.join(base_directory, directories['municipalities']))
municipalities = extract_municipalities_data(municipalities_data)

# Read and extract data from news
news_data = []
for news_dir in directories['news']:
    news_data.extend(read_files_in_directory(os.path.join(base_directory, news_dir)))
news = extract_news_data(news_data)

# Combine all data into a single repository
data_repository = {
    'landmarks': landmarks,
    'municipalities': municipalities,
    'news': news
}

# Save the data repository to a JSON file
with open('puerto_rico_data_repository.json', 'w', encoding='utf-8') as f:
    json.dump(data_repository, f, ensure_ascii=False, indent=4)

print('Data repository created successfully.')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\Latif-Calderón\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:2276, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2275 try:
# -> 2276     tokenizer = cls(*init_inputs, **init_kwargs)
#    2277 except import_protobuf_decode_error():
#
# File c:\Users\Latif-Calderón\anaconda3\Lib\site-packages\transformers\models\t5\tokenization_t5.py:150, in T5Tokenizer.__init__(self, vocab_file, eos_token, unk_token, pad_token, extra_ids, additional_special_tokens, sp_model_kwargs, legacy, add_prefix_space, **kwargs)
#     149 self.sp_model = spm.SentencePieceProcessor(**self.sp_model_kwargs)
# --> 150 self.sp_model.Load(vocab_file)
#     152 if additional_special_tokens is not None:
#
# File c:\Users\Latif-Calderón\anaconda3\Lib\site-packages\sentencepiece\__init__.py:961, in SentencePieceProcessor.Load(self, model_file, model_proto)
#     960   return self.LoadFromSerializedProto(model_proto)
# --> 961 return self.LoadFromFile(model_file)
#
# File c:\Users\Latif-Calderón\anaconda3\Lib\site-packages\sentencepiece\__init__.py:316, in SentencePieceProcessor.LoadFromFile(self, arg)
#     315 def LoadFromFile(self, arg):
# --> 316     return _sentencepiece.SentencePieceProcessor_LoadFromFile(self, arg)
#
# OSError: Not found: "C:\Users\Latif-Calderón\.cache\huggingface\hub\models--t5-small\snapshots\df1b051c49625cf57a3d0d8d3863ed4d13564fe4\spiece.model": No such file or directory Error #2
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 8
#       6 model_name = "t5-small"
#       7 model = T5ForConditionalGeneration.from_pretrained(model_name)
# ----> 8 tokenizer = T5Tokenizer.from_pretrained(model_name)
#      10 def read_files_in_directory(directory):
#      11     data = []
#
# File c:\Users\Latif-Calderón\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:2036, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    2033     else:
#    2034         logger.info(f"loading file {file_path} from cache at {resolved_vocab_files[file_id]}")
# -> 2036 return cls._from_pretrained(
#    2037     resolved_vocab_files,
#    2038     pretrained_model_name_or_path,
#    2039     init_configuration,
#    2040     *init_inputs,
#    2041     token=token,
#    2042     cache_dir=cache_dir,
#    2043     local_files_only=local_files_only,
#    2044     _commit_hash=commit_hash,
#    2045     _is_local=is_local,
#    2046     trust_remote_code=trust_remote_code,
#    2047     **kwargs,
#    2048 )
#
# File c:\Users\Latif-Calderón\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:2291, in PreTrainedTokenizerBase._from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, token, cache_dir, local_files_only, _commit_hash, _is_local, trust_remote_code, *init_inputs, **kwargs)
#    2289     return False
#    2290 except OSError:
# -> 2291     raise OSError(
#    2292         "Unable to load vocabulary from file. "
#    2293         "Please check that the provided vocabulary is accessible and not corrupted."
#    2294     )
#    2295 except RuntimeError as e:
#    2296     if "sentencepiece_processor.cc" in str(e):
#
# OSError: Unable to load vocabulary from file. Please check that the provided vocabulary is accessible and not corrupted.

# %% [markdown]
# ### BART (Bidirectional and Auto-Regressive Transformers): A model designed for sequence-to-sequence tasks, including summarization.

# %%
import os
import json
from transformers import BartForConditionalGeneration, BartTokenizer

# Load the BART model and tokenizer
model_name = "facebook/bart-large-cnn"
model = BartForConditionalGeneration.from_pretrained(model_name)
tokenizer = BartTokenizer.from_pretrained(model_name)

def read_files_in_directory(directory):
    data = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            if not file.endswith('.zip'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    data.append({'file_name': file, 'content': content})
    return data

def summarize_text(text):
    # Preprocess the text for BART
    inputs = tokenizer.encode("summarize: " + text, return_tensors="pt", max_length=1024, truncation=True)
    
    # Generate the summary
    summary_ids = model.generate(inputs, max_length=150, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    
    return summary

def extract_landmarks_data(data):
    landmarks = []
    for item in data:
        summary = summarize_text(item['content'])
        landmarks.append({'file_name': item['file_name'], 'summary': summary})
    return landmarks

def extract_municipalities_data(data):
    municipalities = []
    for item in data:
        summary = summarize_text(item['content'])
        municipalities.append({'file_name': item['file_name'], 'summary': summary})
    return municipalities

def extract_news_data(data):
    news = []
    for item in data:
        summary = summarize_text(item['content'])
        news.append({'file_name': item['file_name'], 'summary': summary})
    return news

base_directory = 'data'
directories = {
    'landmarks': 'landmarks',
    'municipalities': 'municipalities',
    'news': [
        'elmundo_chunked_en_page1_15years',
        'elmundo_chunked_es_page1_15years',
        'elmundo_chunked_es_page1_40years'
    ]
}

# Read and extract data from landmarks
landmarks_data = read_files_in_directory(os.path.join(base_directory, directories['landmarks']))
landmarks = extract_landmarks_data(landmarks_data)

# Read and extract data from municipalities
municipalities_data = read_files_in_directory(os.path.join(base_directory, directories['municipalities']))
municipalities = extract_municipalities_data(municipalities_data)

# Read and extract data from news
news_data = []
for news_dir in directories['news']:
    news_data.extend(read_files_in_directory(os.path.join(base_directory, news_dir)))
news = extract_news_data(news_data)

# Combine all data into a single repository
data_repository = {
    'landmarks': landmarks,
    'municipalities': municipalities,
    'news': news
}

# Save the data repository to a JSON file
with open('puerto_rico_data_repository.json', 'w', encoding='utf-8') as f:
    json.dump(data_repository, f, ensure_ascii=False, indent=4)

print('Data repository created successfully.')
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Failed to interrupt the Kernel.
#
# Unable to start Kernel 'base (Python 3.12.7)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# UI

# %%
import ipywidgets as widgets
from IPython.display import display

# Create chat input and output widgets
chat_input = widgets.Text(description="User Input:")
chat_output = widgets.Output()

# Function to handle user input
def handle_submit(sender):
    user_input = chat_input.value
    with chat_output:
        print(f"User: {user_input}")
        # Add AI processing logic here
        # Display AI response in the chat_output

chat_input.on_submit(handle_submit)

# Display chat UI
display(chat_input, chat_output)
# Out:
# C:\Users\Latif-Calderón\AppData\Local\Temp\ipykernel_18172\1887217869.py:16: DeprecationWarning: on_submit is deprecated. Instead, set the .continuous_update attribute to False and observe the value changing with: mywidget.observe(callback, 'value').
#   chat_input.on_submit(handle_submit)
# Text(value='', description='User Input:')
# Output()

# %%
pip install Flask
# Out:
# Requirement already satisfied: Flask in c:\users\latif-calderón\anaconda3\lib\site-packages (3.0.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\latif-calderón\anaconda3\lib\site-packages (from Flask) (3.0.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\latif-calderón\anaconda3\lib\site-packages (from Flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\latif-calderón\anaconda3\lib\site-packages (from Flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\latif-calderón\anaconda3\lib\site-packages (from Flask) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\latif-calderón\anaconda3\lib\site-packages (from Flask) (1.6.2)
# Requirement already satisfied: colorama in c:\users\latif-calderón\appdata\roaming\python\python312\site-packages (from click>=8.1.3->Flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\latif-calderón\anaconda3\lib\site-packages (from Jinja2>=3.1.2->Flask) (2.1.3)
